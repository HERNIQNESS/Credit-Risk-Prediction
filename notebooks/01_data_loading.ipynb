# %% [markdown]
# ## DATA LOADING
# - getting the data
# - going through to familiarize
# - check datatypes, missing values etc

# %%
import pandas as pd
import numpy as np

# %%
import os
print(os.listdir(r'C:\Users\User\Desktop\credit-risk-project\data\raw'))
# Out:
# ['economic_indicators.csv', 'train.csv']

# %%
# LOADING/READING THE DATA
train = pd.read_csv(r'C:\Users\User\Desktop\credit-risk-project\data\raw\train.csv')
economic = pd.read_csv(r'C:\Users\User\Desktop\credit-risk-project\data\raw\economic_indicators.csv')

print("train loaded:", train.shape)
print("economic loaded:", economic.shape)
# Out:
# train loaded: (68654, 16)
# economic loaded: (27, 25)

# %%
# INSPECTING THE DATA IN TRAIN
print("Shape:", train.shape)
print("\nColumns:", train.columns.tolist())
train.head()
# Out:
# Shape: (68654, 16)
#
# Columns: ['ID', 'customer_id', 'country_id', 'tbl_loan_id', 'lender_id', 'loan_type', 'Total_Amount', 'Total_Amount_to_Repay', 'disbursement_date', 'due_date', 'duration', 'New_versus_Repeat', 'Amount_Funded_By_Lender', 'Lender_portion_Funded', 'Lender_portion_to_be_repaid', 'target']
#                       ID  customer_id country_id  tbl_loan_id  lender_id  \
# 0  ID_257244237466267278       257244      Kenya       237466     267278
# 1  ID_249619214444267278       249619      Kenya       214444     267278
# 2  ID_251457257838267278       251457      Kenya       257838     267278
# 3  ID_266224270337267278       266224      Kenya       270337     267278
# 4  ID_250369246185267278       250369      Kenya       246185     267278
#
#   loan_type  Total_Amount  Total_Amount_to_Repay disbursement_date  \
# 0    Type_1       16477.0                16642.0        2022-08-15
# 1    Type_1        5599.0                 5599.0        2022-07-13
# ...

# %%
# DATA TYPES N MISSING VALUES IN TRAIN
print("Data types:\n", train.dtypes)
print("\nMissing values:\n", train.isnull().sum())
# Out:
# Data types:
#  ID                                 str
# customer_id                      int64
# country_id                         str
# tbl_loan_id                      int64
# lender_id                        int64
# loan_type                          str
# Total_Amount                   float64
# Total_Amount_to_Repay          float64
# disbursement_date                  str
# due_date                           str
# duration                         int64
# New_versus_Repeat                  str
# Amount_Funded_By_Lender        float64
# Lender_portion_Funded          float64
# Lender_portion_to_be_repaid    float64
# target                           int64
# dtype: object
#
# Missing values:
#  ID                             0
# customer_id                    0
# country_id                     0
# tbl_loan_id                    0
# lender_id                      0
# loan_type                      0
# Total_Amount                   0
# Total_Amount_to_Repay          0
# ...

# %%
# UNDERSTANDING TARGET DISTRIBUTION 0'S N 1'S
print("Target distribution:\n", train['target'].value_counts())
print("\nTarget %:\n", train['target'].value_counts(normalize=True) * 100)
# Out:
# Target distribution:
#  target
# 0    67396
# 1     1258
# Name: count, dtype: int64
#
# Target %:
#  target
# 0    98.167623
# 1     1.832377
# Name: proportion, dtype: float64

# %%
# INSPECTING DATA IN ECONOMIC INDICATORS
print("Shape:", economic.shape)
print("\nColumns:", economic.columns.tolist())
economic.head()
# Out:
# Shape: (27, 25)
#
# Columns: ['Country', 'Indicator', 'YR2001', 'YR2002', 'YR2003', 'YR2004', 'YR2005', 'YR2006', 'YR2007', 'YR2008', 'YR2009', 'YR2010', 'YR2011', 'YR2012', 'YR2013', 'YR2014', 'YR2015', 'YR2016', 'YR2017', 'YR2018', 'YR2019', 'YR2020', 'YR2021', 'YR2022', 'YR2023']
#          Country                                          Indicator  \
# 0          Ghana              Inflation, consumer prices (annual %)
# 1  Cote d'Ivoire              Inflation, consumer prices (annual %)
# 2          Kenya              Inflation, consumer prices (annual %)
# 3          Ghana  Official exchange rate (LCU per US$, period av...
# 4  Cote d'Ivoire  Official exchange rate (LCU per US$, period av...
#
#        YR2001      YR2002      YR2003      YR2004      YR2005      YR2006  \
# 0   41.509496    9.360932   29.772980   18.042739   15.438992   11.679184
# 1    4.361529    3.077265    3.296807    1.457988    3.885830    2.467191
# ...
